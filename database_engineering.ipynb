# %%
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session

# %%
weather_df = pd.read_csv('weather_data_clean.csv')
weather_df
# Out:
#            station        date  prcp  tobs                          name  \
# 0      USC00519397  2010-01-01  0.08    65          WAIKIKI 717.2, HI US
# 1      USC00519397  2010-01-02  0.00    63          WAIKIKI 717.2, HI US
# 2      USC00519397  2010-01-03  0.00    74          WAIKIKI 717.2, HI US
# 3      USC00519397  2010-01-04  0.00    76          WAIKIKI 717.2, HI US
# 4      USC00519397  2010-01-07  0.06    70          WAIKIKI 717.2, HI US
# 5      USC00519397  2010-01-08  0.00    64          WAIKIKI 717.2, HI US
# 6      USC00519397  2010-01-09  0.00    68          WAIKIKI 717.2, HI US
# 7      USC00519397  2010-01-10  0.00    73          WAIKIKI 717.2, HI US
# 8      USC00519397  2010-01-11  0.01    64          WAIKIKI 717.2, HI US
# 9      USC00519397  2010-01-12  0.00    61          WAIKIKI 717.2, HI US
# 10     USC00519397  2010-01-14  0.00    66          WAIKIKI 717.2, HI US
# 11     USC00519397  2010-01-15  0.00    65          WAIKIKI 717.2, HI US
# ...

# %%
class weather_station(Base):
    __tablename__ = "Hawaii_Weather"
    id = Column(Integer, primary_key = True)
    station = Column(String)
    date = Column(String)
    prcp = Column(Float)
    tobs = Column(Integer)
    name = Column(String)
    lat = Column(Float)
    lng = Column(Float)
    elevation = Column(Integer)

# %%
engine = create_engine('sqlite:///hawaii.sqlite', echo = False)
Base.metadata.create_all(engine)
session = Session(engine)

# %%
for index, row in weather_df.iterrows():
    print(row['station'])
    session.add(weather_station(station = row['station'], date = row['date'], prcp = row['prcp'], tobs = row['tobs'], name = row['name'], lat = row['latitude'], lng = row['longitude'], elevation = row['elevation']))
# Out:
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# USC00519397
# ...

# %%
#commit added data
session.commit()

# %%
session.query(weather_station.station, weather_station.tobs, weather_station.prcp).filter_by(date = '2012-12-01').all()
# Out:
# [('USC00519397', 65, 0.0),
#  ('USC00513117', 65, 0.0),
#  ('USC00514830', 68, 0.0),
#  ('USC00519523', 77, 0.0),
#  ('USC00519281', 72, 0.0),
#  ('USC00516128', 74, 0.0)]
